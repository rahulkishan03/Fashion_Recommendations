# %%
# !pip install recbole

# %%
import pandas as pd
from google.colab import drive
import numpy as np
from recbole.config import Config
from recbole.data import create_dataset, data_preparation
from recbole.model.sequential_recommender import GRU4Rec
from recbole.trainer import Trainer
from recbole.utils import init_seed
import torch
from recbole.data.interaction import Interaction

# %%
# drive.mount("/content/gdrive")
# pd.set_option('display.max_columns', None)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
### reading the data 
transactions = pd.read_csv("transactions_train.csv", dtype={'article_id': 'str'})
transactions.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  0663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  0541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  0505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  0685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  0685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
### Converting the t_dat from object datatype to timestamp 
transactions['t_dat'] = pd.to_datetime(transactions['t_dat'], format="%Y-%m-%d")
transactions['timestamp'] = transactions.t_dat.values.astype(np.int64) // 10 ** 9

### filtring the data for 2020 
df_2020 = transactions[transactions['timestamp'] > 1585620000][['customer_id', 'article_id', 'timestamp']].rename(columns={'customer_id': 'user_id:token', 'article_id': 'item_id:token', 'timestamp': 'timestamp:float'})
df_2020.head()
# Out:
#                                               user_id:token item_id:token  \
# 23934157  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...    0727808001
# 23934158  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...    0727808007
# 23934159  000563485cbb7850b0a93c6606f89c5b961c6647d1bd48...    0567532015
# 23934160  000563485cbb7850b0a93c6606f89c5b961c6647d1bd48...    0706104009
# 23934161  00083cda041544b2fbb0e0d2905ad17da7cf1007526fb4...    0783504004
#
#           timestamp:float
# 23934157       1585699200
# 23934158       1585699200
# 23934159       1585699200
# 23934160       1585699200
# 23934161       1585699200

# %%
### Saving the data in the format to be used by Recbole 
df_2020.to_csv('recbox_data/recbox_data.inter', index=False, sep='\t')
# Out:
# 249

# %% [markdown]
# ### Create dataset and train model with Recbole

# %%
### Parameter to configure data for Recbole 
parameter_dict = {
    'data_path': './', ## path of the dataset 
    'USER_ID_FIELD': 'user_id', ## user ID 
    'ITEM_ID_FIELD': 'item_id', ## item ID filed 
    'TIME_FIELD': 'timestamp', ## Timestamp 
    'user_inter_num_interval': "[40,inf)", ##  users who buy more than 40 items 
    'item_inter_num_interval': "[40,inf)", ## items which is bought by more than 40 people 
    'load_col': {'inter': ['user_id', 'item_id', 'timestamp']},
    'neg_sampling': None,
    'epochs': 50,  ## number of epochs to be used to train the model 
    'eval_args': {
        'split': {'RS': [10, 0, 0]}, ### split the data into only train, no test, no validation 
        'group_by': 'user', ### groupby using user 
        'order': 'TO',
        'mode': 'full'}
}

### creating the data configuration 
config = Config(model='GRU4Rec', dataset='recbox_data', config_dict=parameter_dict)

# random seed
init_seed(config['seed'], config['reproducibility'])

# %%
### creating dataset based on above configuration 
dataset = create_dataset(config)

# %%
### splitting the data into test, train and validation 
train_data, valid_data, test_data = data_preparation(config, dataset)
# Out:
# 11 May 19:33    INFO  [Training]: train_batch_size = [2048] negative sampling: [None]
# [Training]: train_batch_size = [2048] negative sampling: [None]
# 11 May 19:33    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [10, 0, 0]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [10, 0, 0]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]

# %%
model = GRU4Rec(config, train_data.dataset).to(config['device'])
# logger.info(model)

# trainer loading and initialization
trainer = Trainer(config, model)

# model training
best_valid_score, best_valid_result = trainer.fit(train_data)
# Out:
# 11 May 19:34    INFO  epoch 0 training [time: 15.51s, train loss: 3720.7215]
# epoch 0 training [time: 15.51s, train loss: 3720.7215]
# 11 May 19:34    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:34    INFO  epoch 1 training [time: 15.78s, train loss: 3532.7930]
# epoch 1 training [time: 15.78s, train loss: 3532.7930]
# 11 May 19:34    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:34    INFO  epoch 2 training [time: 15.82s, train loss: 3386.4065]
# epoch 2 training [time: 15.82s, train loss: 3386.4065]
# 11 May 19:34    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:34    INFO  epoch 3 training [time: 15.92s, train loss: 3294.3650]
# epoch 3 training [time: 15.92s, train loss: 3294.3650]
# 11 May 19:34    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:35    INFO  epoch 4 training [time: 16.19s, train loss: 3222.5344]
# epoch 4 training [time: 16.19s, train loss: 3222.5344]
# 11 May 19:35    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:35    INFO  epoch 5 training [time: 16.35s, train loss: 3161.2702]
# epoch 5 training [time: 16.35s, train loss: 3161.2702]
# 11 May 19:35    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:35    INFO  epoch 6 training [time: 16.27s, train loss: 3108.7235]
# epoch 6 training [time: 16.27s, train loss: 3108.7235]
# 11 May 19:35    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:35    INFO  epoch 7 training [time: 16.17s, train loss: 3066.4591]
# epoch 7 training [time: 16.17s, train loss: 3066.4591]
# 11 May 19:35    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:36    INFO  epoch 8 training [time: 16.10s, train loss: 3031.2710]
# epoch 8 training [time: 16.10s, train loss: 3031.2710]
# 11 May 19:36    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:36    INFO  epoch 9 training [time: 16.16s, train loss: 3000.4959]
# epoch 9 training [time: 16.16s, train loss: 3000.4959]
# 11 May 19:36    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:36    INFO  epoch 10 training [time: 16.22s, train loss: 2974.8172]
# epoch 10 training [time: 16.22s, train loss: 2974.8172]
# 11 May 19:36    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:37    INFO  epoch 11 training [time: 16.24s, train loss: 2952.9540]
# epoch 11 training [time: 16.24s, train loss: 2952.9540]
# 11 May 19:37    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:37    INFO  epoch 12 training [time: 16.25s, train loss: 2933.5237]
# epoch 12 training [time: 16.25s, train loss: 2933.5237]
# 11 May 19:37    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:37    INFO  epoch 13 training [time: 16.25s, train loss: 2915.7234]
# epoch 13 training [time: 16.25s, train loss: 2915.7234]
# 11 May 19:37    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:37    INFO  epoch 14 training [time: 16.24s, train loss: 2899.8464]
# epoch 14 training [time: 16.24s, train loss: 2899.8464]
# 11 May 19:37    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:38    INFO  epoch 15 training [time: 16.22s, train loss: 2885.3249]
# epoch 15 training [time: 16.22s, train loss: 2885.3249]
# 11 May 19:38    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:38    INFO  epoch 16 training [time: 16.24s, train loss: 2872.2667]
# epoch 16 training [time: 16.24s, train loss: 2872.2667]
# 11 May 19:38    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:38    INFO  epoch 17 training [time: 16.22s, train loss: 2860.1438]
# epoch 17 training [time: 16.22s, train loss: 2860.1438]
# 11 May 19:38    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:38    INFO  epoch 18 training [time: 16.26s, train loss: 2848.7991]
# epoch 18 training [time: 16.26s, train loss: 2848.7991]
# 11 May 19:38    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:39    INFO  epoch 19 training [time: 16.22s, train loss: 2838.3497]
# epoch 19 training [time: 16.22s, train loss: 2838.3497]
# 11 May 19:39    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:39    INFO  epoch 20 training [time: 16.23s, train loss: 2828.6200]
# epoch 20 training [time: 16.23s, train loss: 2828.6200]
# 11 May 19:39    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:39    INFO  epoch 21 training [time: 16.24s, train loss: 2820.0519]
# epoch 21 training [time: 16.24s, train loss: 2820.0519]
# 11 May 19:39    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:40    INFO  epoch 22 training [time: 16.21s, train loss: 2811.6311]
# epoch 22 training [time: 16.21s, train loss: 2811.6311]
# 11 May 19:40    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:40    INFO  epoch 23 training [time: 16.21s, train loss: 2803.4757]
# epoch 23 training [time: 16.21s, train loss: 2803.4757]
# 11 May 19:40    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:40    INFO  epoch 24 training [time: 16.25s, train loss: 2797.6715]
# epoch 24 training [time: 16.25s, train loss: 2797.6715]
# 11 May 19:40    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:40    INFO  epoch 25 training [time: 16.21s, train loss: 2790.8273]
# epoch 25 training [time: 16.21s, train loss: 2790.8273]
# 11 May 19:40    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:41    INFO  epoch 26 training [time: 16.23s, train loss: 2785.0997]
# epoch 26 training [time: 16.23s, train loss: 2785.0997]
# 11 May 19:41    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:41    INFO  epoch 27 training [time: 16.23s, train loss: 2779.9311]
# epoch 27 training [time: 16.23s, train loss: 2779.9311]
# 11 May 19:41    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:41    INFO  epoch 28 training [time: 16.22s, train loss: 2774.6431]
# epoch 28 training [time: 16.22s, train loss: 2774.6431]
# 11 May 19:41    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:41    INFO  epoch 29 training [time: 16.20s, train loss: 2770.5704]
# epoch 29 training [time: 16.20s, train loss: 2770.5704]
# 11 May 19:41    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:42    INFO  epoch 30 training [time: 16.23s, train loss: 2765.9028]
# epoch 30 training [time: 16.23s, train loss: 2765.9028]
# 11 May 19:42    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:42    INFO  epoch 31 training [time: 16.22s, train loss: 2762.6724]
# epoch 31 training [time: 16.22s, train loss: 2762.6724]
# 11 May 19:42    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:42    INFO  epoch 32 training [time: 16.23s, train loss: 2759.4641]
# epoch 32 training [time: 16.23s, train loss: 2759.4641]
# 11 May 19:42    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:42    INFO  epoch 33 training [time: 16.19s, train loss: 2756.1286]
# epoch 33 training [time: 16.19s, train loss: 2756.1286]
# 11 May 19:42    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:43    INFO  epoch 34 training [time: 16.21s, train loss: 2752.8714]
# epoch 34 training [time: 16.21s, train loss: 2752.8714]
# 11 May 19:43    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:43    INFO  epoch 35 training [time: 16.20s, train loss: 2749.4546]
# epoch 35 training [time: 16.20s, train loss: 2749.4546]
# 11 May 19:43    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:43    INFO  epoch 36 training [time: 16.20s, train loss: 2746.9521]
# epoch 36 training [time: 16.20s, train loss: 2746.9521]
# 11 May 19:43    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:44    INFO  epoch 37 training [time: 16.22s, train loss: 2744.0462]
# epoch 37 training [time: 16.22s, train loss: 2744.0462]
# 11 May 19:44    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:44    INFO  epoch 38 training [time: 16.23s, train loss: 2742.1070]
# epoch 38 training [time: 16.23s, train loss: 2742.1070]
# 11 May 19:44    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:44    INFO  epoch 39 training [time: 16.24s, train loss: 2739.4924]
# epoch 39 training [time: 16.24s, train loss: 2739.4924]
# 11 May 19:44    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:44    INFO  epoch 40 training [time: 16.25s, train loss: 2737.7506]
# epoch 40 training [time: 16.25s, train loss: 2737.7506]
# 11 May 19:44    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:45    INFO  epoch 41 training [time: 16.24s, train loss: 2735.7073]
# epoch 41 training [time: 16.24s, train loss: 2735.7073]
# 11 May 19:45    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:45    INFO  epoch 42 training [time: 16.26s, train loss: 2733.2025]
# epoch 42 training [time: 16.26s, train loss: 2733.2025]
# 11 May 19:45    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:45    INFO  epoch 43 training [time: 16.19s, train loss: 2731.2657]
# epoch 43 training [time: 16.19s, train loss: 2731.2657]
# 11 May 19:45    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:45    INFO  epoch 44 training [time: 16.24s, train loss: 2729.1587]
# epoch 44 training [time: 16.24s, train loss: 2729.1587]
# 11 May 19:45    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:46    INFO  epoch 45 training [time: 16.22s, train loss: 2728.2633]
# epoch 45 training [time: 16.22s, train loss: 2728.2633]
# 11 May 19:46    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:46    INFO  epoch 46 training [time: 16.24s, train loss: 2726.0009]
# epoch 46 training [time: 16.24s, train loss: 2726.0009]
# 11 May 19:46    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:46    INFO  epoch 47 training [time: 16.24s, train loss: 2724.4091]
# epoch 47 training [time: 16.24s, train loss: 2724.4091]
# 11 May 19:46    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:47    INFO  epoch 48 training [time: 16.26s, train loss: 2722.4091]
# epoch 48 training [time: 16.26s, train loss: 2722.4091]
# 11 May 19:47    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# 11 May 19:47    INFO  epoch 49 training [time: 16.24s, train loss: 2720.9313]
# epoch 49 training [time: 16.24s, train loss: 2720.9313]
# 11 May 19:47    INFO  Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth
# Saving current: saved/GRU4Rec-May-11-2022_19-33-48.pth

# %% [markdown]
# Create recommendation result from trained model

# %%
### list of all the customer ID
external_user_ids = dataset.id2token(dataset.uid_field, list(range(dataset.user_num)))[1:]

# %%
###
# Input:
# old_interaction: list of all previous transaction 
# last_item_id: last trainstion article ID
# max_len: Max number of transaction 

def add_last_item(old_interaction, last_item_id, max_len=50):
    new_seq_items = old_interaction['item_id_list'][-1]
    if old_interaction['item_length'][-1].item() < max_len:
        new_seq_items[old_interaction['item_length'][-1].item()] = last_item_id
    else:
        new_seq_items = torch.roll(new_seq_items, -1)
        new_seq_items[-1] = last_item_id
    return new_seq_items.view(1, len(new_seq_items))

### 
#input:
# external_user_id : List of all customer ID
# dataset : Atomic dataset 
# Model : recbole model object 

def predict_for_all_item(external_user_id, dataset, model):
    model.eval()
    with torch.no_grad():
        uid_series = dataset.token2id(dataset.uid_field, [external_user_id])
        index = np.isin(dataset[dataset.uid_field].numpy(), uid_series)
        input_interaction = dataset[index]
        test = {
            'item_id_list': add_last_item(input_interaction, 
                                          input_interaction['item_id'][-1].item(), model.max_seq_length),
            'item_length': torch.tensor(
                [input_interaction['item_length'][-1].item() + 1
                 if input_interaction['item_length'][-1].item() < model.max_seq_length else model.max_seq_length])
        }
        new_inter = Interaction(test)
        new_inter = new_inter.to(config['device'])
        new_scores = model.full_sort_predict(new_inter)
        new_scores = new_scores.view(-1, test_data.dataset.item_num)
        new_scores[:, 0] = -np.inf  # set scores of [pad] to -inf
    return torch.topk(new_scores, 10)

# %%
topk_items = []
### Looping thorugh all the customer ID 
for external_user_id in external_user_ids:
    _, topk_iid_list = predict_for_all_item(external_user_id, dataset, model)
    last_topk_iid_list = topk_iid_list[-1]
    external_item_list = dataset.id2token(dataset.iid_field, last_topk_iid_list.cpu()).tolist()
    topk_items.append(external_item_list)
# Out:
# 15458

# %%
external_item_str = [' '.join(x) for x in topk_items]
result = pd.DataFrame(external_user_ids, columns=['customer_id'])
result['prediction'] = external_item_str
result.head()
# Out:
#                                          customer_id  \
# 0  00d7ebd46f6a6d53630d41386b6ef6a505cdc4c80011ff...
# 1  0109ad0b5a76924a1b58be677409bb601cc8bead9a87b8...
# 2  013f00f9e218549246a3aa82b3f3a0c22a693bc25fa735...
# 3  01bada2a453b09c70ea57bdda5a9ef0fb04062718d3a3d...
# 4  01dd96059a11759518f10969d0a528f03c8501dc4c628b...
#
#                                           prediction
# 0  0918522001 0850917001 0893133001 0915526001 09...
# 1  0901955001 0861477001 0600886001 0833530002 07...
# 2  0839402002 0839402001 0770336001 0865172002 08...
# 3  0724906006 0253448003 0554598001 0700701002 08...
# 4  0817353003 0895002002 0842004003 0859118001 08...

# %% [markdown]
# Combine result from most bought items and GRU model

# %%
### using the submission file from ensamble model 
submit_df = pd.read_csv('submission.csv')

## Merging the ensamble model prediction with prediction
submit_df = pd.merge(submit_df, result, on='customer_id', how='outer')
submit_df.head()
# Out:
# (1371980, 2)

# %%
submit_df = submit_df.fillna(-1)
submit_df['prediction'] = submit_df.apply(
    lambda x: x['prediction_y'] if x['prediction_y'] != -1 else x['prediction_x'], axis=1)
submit_df.head()
# Out:
#                                          customer_id  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#
#                                         prediction_x prediction_y  \
# 0  0568601043 0568601006 0751471001 0924243001 04...           -1
# 1  0826211002 0924243001 0924243002 0739590027 08...           -1
# 2  0794321007 0852643001 0924243001 0924243002 07...           -1
# 3  0448509014 0924243002 0924243001 0751471001 05...           -1
# 4  0730683050 0791587015 0927530004 0896152002 09...           -1
#
#                                           prediction
# 0  0568601043 0568601006 0751471001 0924243001 04...
# 1  0826211002 0924243001 0924243002 0739590027 08...
# 2  0794321007 0852643001 0924243001 0924243002 07...
# 3  0448509014 0924243002 0924243001 0751471001 05...
# 4  0730683050 0791587015 0927530004 0896152002 09...

# %%
submit_df = submit_df.drop(columns=['prediction_y', 'prediction_x'])
submit_df.head()
# Out:
#                                          customer_id  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#
#                                           prediction
# 0  0568601043 0568601006 0751471001 0924243001 04...
# 1  0826211002 0924243001 0924243002 0739590027 08...
# 2  0794321007 0852643001 0924243001 0924243002 07...
# 3  0448509014 0924243002 0924243001 0751471001 05...
# 4  0730683050 0791587015 0927530004 0896152002 09...

# %%
submit_df.to_csv('submission_regbole.csv', index=False)
